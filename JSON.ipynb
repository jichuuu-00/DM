# %% [markdown]
# ## JSON

# %%
import requests

client_id = '0yhn9rQGesj92gcDKxHv'
client_secret = '_jGFm9sLbD'

naver_api = 'https://openapi.naver.com/v1/search/news.json?query=covid'
header_para = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret}

res = requests.get(naver_api, headers = header_para)
#res.content
res.json()
# Out:
# {'lastBuildDate': 'Tue, 17 May 2022 23:49:03 +0900',
#  'total': 541008,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': 'Virus Outbreak Kid Vaccine Booster',
#    'originallink': '',
#    'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=104&oid=077&aid=0005587986',
#    'description': 'FILE - A nurse holds a vial of the Pfizer <b>COVID</b>-19 vaccine for children ages 5 to 11, right, and... regulators authorized a <b>COVID</b>-19 booster shot for healthy 5- to 11-year-olds on Tuesday, May 17... ',
#    'pubDate': 'Tue, 17 May 2022 23:45:00 +0900'},
#   {'title': 'Poor Countries Face a Mounting Catastrophe Fueled by Inflation and Debt',
#    'originallink': 'https://www.nytimes.com/2022/05/17/business/inflation-developing-economies.html?partner=naver',
#    'link': 'https://www.nytimes.com/2022/05/17/business/inflation-developing-economies.html?partner=naver',
# ...

# %%
import json

# %%
data = """
{
    "id":"01", "language": "Java", "edition": "third", "author": "Herbert Schildt",
    "history":
    [{
        "date": "2021-04-03",
        "item": "iPhone"
    
    },
    {
        "date": "2022-05-03",
        "item": "ANDROID"    
    }    
    ]
}
"""

# %%
json_data = json.loads(data)

# %%
print(json_data['id'])
print(json_data['language'])
print(json_data['history'])
print(json_data['history'][0])
print(json_data['history'][0]['item'])
# Out:
# 01
# Java
# [{'date': '2021-04-03', 'item': 'iPhone'}, {'date': '2022-05-03', 'item': 'ANDROID'}]
# {'date': '2021-04-03', 'item': 'iPhone'}
# iPhone
