# %% [markdown]
# ## Dictionary
#
# * Create
# * Read
# * Append
# * Remove
# * Update
# * Others

# %%
data_list = list()

# %%
data_dict = dict()

# %%
data_dict = {'Name': 'Ben', 'Dept': 'DIGB', 'GPA': '4.0'} #dictionary

# %%
location = ['Seoul', 'Sejong', 'Pusan'] #list
location.append('Incheon')

# %%
location
# Out:
# ['Seoul', 'Sejong', 'Pusan', 'Incheon']

# %% [markdown]
# ## Read a Dict

# %%
data_dict['Name']
# Out:
# 'Ben'

# %% [markdown]
# ## Append

# %%
data_dict['Course'] = 'DM'

# %%
data_dict
# Out:
# {'Name': 'Ben', 'Dept': 'DIGB', 'GPA': '4.0', 'Course': 'DM'}

# %% [markdown]
# ## Remove

# %%
del data_dict['GPA']

# %%
data_dict
# Out:
# {'Name': 'Ben', 'Dept': 'DIGB', 'Course': 'DM'}

# %% [markdown]
# ## Update

# %%
data_dict['DIGB'] = 'DDM'

# %%
data_dict
# Out:
# {'Name': 'Ben', 'Dept': 'DIGB', 'Course': 'DM', 'DIGB': 'DDM'}

# %%
del data_dict['DIGB']

# %%
data_dict
# Out:
# {'Name': 'Ben', 'Dept': 'DIGB', 'Course': 'DM'}

# %%
data_dict['Dept'] = 'DDM'

# %%
data_dict
# Out:
# {'Name': 'Ben', 'Dept': 'DDM', 'Course': 'DM'}

# %% [markdown]
# ## Others
#
# * keys only
# * values only

# %%
data_dict.keys()
# Out:
# dict_keys(['Name', 'Dept', 'Course'])

# %%
data_dict.values()
# Out:
# dict_values(['Ben', 'DDM', 'DM'])
