# %%
article = "BTS were the big winners at Sunday's American Music Awards, picking up three prizes including artist of the year.

The South Korean band also won best pop group for the third year in a row, and best pop song for their chart-topping dance anthem, Butter.

"This whole thing is a miracle," said singer RM. "Seriously, we'll never take this for granted."

Taylor Swift won best female pop artist for the sixth time, also taking home best pop album for Evermore.

Those two prizes brought Swift's total tally of American Music Awards to 34, extending her lead as the artist with the most wins. Michael Jackson is in second place with 26 wins.

She also previously won artist of the decade in 2019. Accepting the best pop album prize on Sunday, the star described Evermore as the "adventurous, fun younger sister" to her lockdown album Folklore, which won album of the year at the Grammys in March.

The star also thanked fans for their support, saying: "I'm so lucky to be in your life and to get to have you in mine."
"
# Out:
#   File "<ipython-input-3-d2ee145ac96b>", line 1
#     article = "BTS were the big winners at Sunday's American Music Awards, picking up three prizes including artist of the year.
#                                                                                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
#variable
article = '''BTS were the big winners at Sunday's American Music Awards, picking up three prizes including artist of the year.

The South Korean band also won best pop group for the third year in a row, and best pop song for their chart-topping dance anthem, Butter.

"This whole thing is a miracle," said singer RM. "Seriously, we'll never take this for granted."

Taylor Swift won best female pop artist for the sixth time, also taking home best pop album for Evermore.

Those two prizes brought Swift's total tally of American Music Awards to 34, extending her lead as the artist with the most wins. Michael Jackson is in second place with 26 wins.

She also previously won artist of the decade in 2019. Accepting the best pop album prize on Sunday, the star described Evermore as the "adventurous, fun younger sister" to her lockdown album Folklore, which won album of the year at the Grammys in March.

The star also thanked fans for their support, saying: "I'm so lucky to be in your life and to get to have you in mine.'''

# %%
article.count("BTS")
#객체지향 object-orientned programming(OOP)
# Out:
# 1

# %%
article.count("bts")
# Out:
# 0

# %%
article.count("Swift")
# Out:
# 2

# %%
print(article.count("BTS"))
# Out:
# 1

# %% [markdown]
# ## len : number of characters

# %%
print(len(article))
# Out:
# 1015

# %% [markdown]
# ## Indexing & Slicing

# %%
print(article[0])
# Out:
# B

# %%
print(article[-1])

# %%
#문자열 string
string = "Python"

# %%
print(string)
# Out:
# python

# %%
#3rd position
print(string[2])
# Out:
# t

# %%
print(string[2:4])
#strings positioned from 2nd to 3rd
# Out:
# th

# %% [markdown]
# ## strip function

# %%
string2 = "    Hello Python    "

# %%
print(string2)
# Out:
#     Hello Python

# %%
print(string2.strip())
# Out:
# Hello Python

# %% [markdown]
# ## Data Type: List
#
# * CRUD
# * C:Create
# * R:Read
# * U:Update
# * D:Delete

# %% [markdown]
# ## 1) Create a new list

# %%
data_list = list()

# %%
location = ['Seoul', 'Sejong', 'Pusan']

# %%
print(location)
# Out:
# ['Seoul', 'Sejong', 'Pusan']

# %% [markdown]
# ## 2) Append: Add a new element in a list

# %%
location.append('Tokyo')

# %%
location
# Out:
# ['Seoul', 'Sejong', 'Pusan', 'Tokyo']

# %%
location.append('Kyoto')

# %%
location
# Out:
# ['Seoul', 'Sejong', 'Pusan', 'Tokyo', 'Kyoto']

# %%
location[2:5] #slicing list
# Out:
# ['Pusan', 'Tokyo', 'Kyoto']

# %% [markdown]
# ## 3) Delete elements in a list

# %%
location
# Out:
# ['Seoul', 'Sejong', 'Pusan', 'Tokyo', 'Kyoto']

# %%
location.remove('Pusan')

# %%
location
# Out:
# ['Seoul', 'Sejong', 'Tokyo', 'Kyoto']

# %%
del location[3]

# %%
location
# Out:
# ['Seoul', 'Sejong', 'Tokyo']

# %% [markdown]
# ## 4) Update elements

# %%
location
# Out:
# ['Seoul', 'Sejong', 'Tokyo']

# %%
location[1] = 'Daejon'

# %%
location
# Out:
# ['Seoul', 'Daejon', 'Tokyo']

# %%
data_list
# Out:
# []

# %%
data_list.append('Seoul')

# %%
data_list
# Out:
# ['Seoul']

# %%
data_list.append('Incheon')

# %%
data_list
# Out:
# ['Seoul', 'Incheon']

# %% [markdown]
# ## Various types of data
#
# * string
# * integer 정수
# * float 소수점
# * boolean

# %%
data2 = ['Seoul', 7, 2.78, True]

# %% [markdown]
# ## Exercise

# %%
lang = ['java', 'c', 'html']

# %%
del lang[1]

# %%
lang
# Out:
# ['java', 'html']

# %%
lang.append('python')

# %%
lang
# Out:
# ['java', 'html', 'python']
