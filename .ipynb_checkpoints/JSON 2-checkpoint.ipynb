# %% [markdown]
# ## JSON

# %%
import requests

client_id = '0yhn9rQGesj92gcDKxHv'
client_secret = '_jGFm9sLbD'

naver_api = 'https://openapi.naver.com/v1/search/news.json?query=covid'
params = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret}

res = requests.get(naver_api, headers = params)
res.json()
#res.text()
# Out:
# {'lastBuildDate': 'Wed, 18 May 2022 00:06:17 +0900',
#  'total': 541009,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': 'The F.D.A. authorizes Pfizer-BioNTech boosters for children ages 5 to 11...',
#    'originallink': 'https://www.nytimes.com/2022/05/17/us/politics/fda-pfizer-booster-children.html?partner=naver',
#    'link': 'https://www.nytimes.com/2022/05/17/us/politics/fda-pfizer-booster-children.html?partner=naver',
#    'description': 'Although they have been eligible for <b>Covid</b> shots since November, only 29 percent of 5- to 11... Califf, the F.D.A.’s commissioner, said: “While it has largely been the case that <b>Covid</b>-19... ',
#    'pubDate': 'Tue, 17 May 2022 23:50:00 +0900'},
#   {'title': 'Virus Outbreak Kid Vaccine Booster',
#    'originallink': '',
#    'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=104&oid=077&aid=0005587986',
# ...

# %%
import requests

client_id = '0yhn9rQGesj92gcDKxHv'
client_secret = '_jGFm9sLbD'

naver_api = 'https://openapi.naver.com/v1/search/news.json?query=covid'
params = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret}

res = requests.get(naver_api, headers = params)

if res.status_code == 200:
    data = res.json()
    for item in data['items']:
        print(item['title'], item['link'])
else:
    print("Error Code:". res.status_code)
# Out:
# Pennsylvania’s attorney general, a candidate for governor, is isolating... https://www.nytimes.com/2022/05/17/us/politics/pennsylvania-attorney-general-shapiro-covid.html?partner=naver
# The F.D.A. authorizes Pfizer-BioNTech boosters for children ages 5 to 11... https://www.nytimes.com/2022/05/17/us/politics/fda-pfizer-booster-children.html?partner=naver
# Virus Outbreak Kid Vaccine Booster https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=104&oid=077&aid=0005587986
# Poor Countries Face a Mounting Catastrophe Fueled by Inflation and Debt https://www.nytimes.com/2022/05/17/business/inflation-developing-economies.html?partner=naver
# The Baby Formula Shortage: What Can Be Done https://www.nytimes.com/2022/05/17/opinion/letters/baby-formula-shortage.html?partner=naver
# Why the Tonys Need an Award for Best Ensemble https://www.nytimes.com/2022/05/17/theater/tony-awards-2022.html?partner=naver
# ...
